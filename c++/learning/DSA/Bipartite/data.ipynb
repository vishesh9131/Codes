# %%
import pandas as pd
# Out:
# /Users/visheshyadav/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd.read_csv("usecasesimp/pop.csv")
# Out:
#           Category
# 0        Solo Male
# 1      Solo Female
# 2         Boy Band
# 3       Girl Group
# 4              Duo
# 5   Electronic Pop
# 6        Indie Pop
# 7            K-Pop
# 8         Teen Pop
# 9        Dance Pop
# 10       Solo Male
# 11     Solo Female
# 12        Boy Band
# 13      Girl Group
# 14             Duo
# 15  Electronic Pop
# 16       Indie Pop
# 17           K-Pop
# 18        Teen Pop
# 19       Dance Pop
# 20       Solo Male
# 21     Solo Female
# 22        Boy Band
# 23      Girl Group
# 24             Duo
# 25  Electronic Pop
# 26       Indie Pop
# 27           K-Pop
# 28        Teen Pop
# 29       Dance Pop
# 30       Solo Male
# 31     Solo Female
# 32        Boy Band
# 33      Girl Group
# 34             Duo
# 35  Electronic Pop
# 36       Indie Pop
# 37           K-Pop
# 38        Teen Pop
# 39       Dance Pop
# 40       Solo Male
# 41     Solo Female
# 42        Boy Band
# 43      Girl Group
# 44             Duo
# 45  Electronic Pop
# ...
