# %%
import numpy as np 
import pandas as pd
import warnings
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

warnings.simplefilter('ignore', DeprecationWarning)

# %%
df=pd.read_csv("kyphosis_Dataset.csv")

# %%
df
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
kyphosis_counts = df['Kyphosis'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(kyphosis_counts, labels=kyphosis_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Kyphosis')
plt.axis('equal') 
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
X = pd.read_csv('kyphosis_Dataset.csv')
y = X['Kyphosis']
X = X.drop('Kyphosis', axis=1)

# %%
# i will ignore all the mac afs warning from herre
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, message="is_sparse")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=203)

model = DecisionTreeClassifier(random_state=10)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
prediction = model.predict([[128, 4, 5]])
print(prediction[0])
# Out:
# present
# /Users/visheshyadav/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       absent       0.95      0.95      0.95        22
#      present       0.67      0.67      0.67         3
#
#     accuracy                           0.92        25
#    macro avg       0.81      0.81      0.81        25
# weighted avg       0.92      0.92      0.92        25

# %%
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[21  1]
#  [ 1  2]]

# %%
fig = plt.figure(figsize=(15,10))
plot_tree(model, feature_names=X.columns, class_names=['absent','present'], filled=True, rounded=True, precision=2, ax=fig.add_subplot(111))
plt.show()

# %%
df.head(18)
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# 5    absent    1       2     16
# 6    absent   61       2     17
# 7    absent   37       3     16
# 8    absent  113       2     16
# 9   present   59       6     12
# 10  present   82       5     14
# 11   absent  148       3     16
# 12   absent   18       5      2
# 13   absent    1       4     12
# 14   absent  168       3     18
# 15   absent    1       3     16
# 16   absent   78       6     15
# 17   absent  175       5     13

# %%
age = float(input("Enter patient's age: "))
number = float(input("Enter number of vertebrae involved: "))
start = float(input("Enter the starting vertebrae: "))

prediction = model.predict([[age, number, start]])

if prediction[0] == 'present':
    print("present")
else:
    print("absent")
# Out:
# present
# /Users/visheshyadav/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
